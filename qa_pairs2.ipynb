# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/mnt/c/users/ankku/Documents/WiDS-2024/moneycontrol_companies.csv")  # Replace with your file path
data
# Out:
#                                                  Title  \
# 0    Intellect Design shares up 10% on strong volum...
# 1    Novo Nordisk falls most on record after new we...
# 2    Centre must push states to comply with renewab...
# 3    FedEx plans to spin off $30 billion freight un...
# 4    Tata Steel Netherlands faces penalty of almost...
# ..                                                 ...
# 528  Motherson may join Apple supply chain in India...
# 529  State Bank of India deploys 2,000 bankers to w...
# 530  Dell cuts workers in sales team reorganization...
# 531  Airtel delays call for rs 15,000 crore rights ...
# 532  Adani Energy Solutions raises $1 bn via QIP to...
#
#                                               Abstract  \
# 0    Last week, the company shared a presentation w...
# 1    The shot helped patients lose an average of 20...
# 2    The industry has sought transmission charges w...
# 3    FedEx said it will separate the unit, which is...
# 4    Tata Steel has called the penalty imposed on i...
# ..                                                 ...
# 528  The venture targets a turnover of Rs 8,000-8,5...
# 529  The bank’s wealth management unit is “old” and...
# 530  The company’s best-known business of selling p...
# 531  India’s second-largest telecom operator highli...
# 532  The QIP was launched after market hours on Jul...
#
#                                                Content
# 0    Shares of software development firm Intellect ...
# 1    Novo Nordisk’s shares fell by the most on reco...
# 2    Piling unsigned power purchase agreements (PPA...
# 3    FedEx Corp. shares soared after the company sa...
# 4    Tata Steel Nederland is staring at a penalty o...
# ..                                                 ...
# 528  The Motherson Group is on the verge of enterin...
# 529  State Bank of India, the country’s largest len...
# 530  Dell Technologies Inc. is cutting jobs as part...
# 531  The Bharti Airtel board has decided not to cal...
# 532  Adani Energy Solutions on August 5 said it has...
#
# [533 rows x 3 columns]

# %%
from transformers import pipeline, T5Tokenizer, T5ForConditionalGeneration
import nltk

# Download sentence tokenizer
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize

# Load question generation model
qa_pairs = []
for i in range(480, len(data)):
    print(i)
    model_name = "mrm8488/t5-base-finetuned-question-generation-ap"
    tokenizer = T5Tokenizer.from_pretrained(model_name)
    model = T5ForConditionalGeneration.from_pretrained(model_name)
    qg_pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer)

    # Load question-answering model
    qa_pipeline = pipeline("question-answering", model="distilbert-base-uncased-distilled-squad")

    # Input content
    abstract = data.loc[i, 'Abstract']
    # print(abstract)

    # Split content into sentences
    sentences = sent_tokenize(abstract)

    # Generate questions and answers
    for sentence in sentences:
        # Generate question
        result = qg_pipeline(f"generate question: {sentence}")
        question = result[0]['generated_text']
        print(question)

        # Generate answer
        answer = qa_pipeline(question=question, context=abstract)['answer']
        print(answer)

        # Save question-answer pair
        qa_pairs.append((question, answer))

# print(qa_pairs)
# Out:
# [nltk_data] Downloading package punkt to /home/ank/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/ank/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 480
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: How much money has KRAFTON invested in Indian startups?
# $160 million
# 481
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the BSA's relaunch in 2021?
# BSA was relaunched in 2021
# question: What is the name of the brand that is owned by Classic Legends?
# Jawa and Yezdi motorcycle
# 482
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the increase in the subscriber base in Q1FY24?
# 122.9 million
# 483
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the growth of the construction chemicals and waterproofing segments?
# strong
# 484
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the future of stock returns?
# once-reliable
# 485
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the trend of Indian food delivery?
# shifting away from rigid statistical norms, embracing diverse and fusion cuisines
# question: What is the impact of the new offerings?
# growing consumer appetite for variety
# 486
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What kind of EVs will Gentari deploy for Amazon?
# pact
# 487
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What did the integrated producer say it was unable to comment on media speculation?
# rumors
# 488
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: How much did the company raise in a round led by Force Ventures?
# Rs 11 crore
# 489
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What did the NCLT order do?
# permitting the reclassification and transfer of funds from general reserves to retained earnings
# question: How much debt did Hindustan Zinc have as of March 31, 2024?
# Rs 8,722 crore
# 490
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the SEBI's response to the Adani case?
# This comment
# 491
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the amount of funding the IIHL submitted to the Monitoring Committee?
# Rs 7,300 crore
# question: What was the deadline for the term sheet?
# 4 p.m. on August 8
# 492
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What did Hindenburg's report suggest about Adani's confidence in operating without
# Adani's confidence in operating without serious regulatory intervention
# 493
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What type of income can a REIT generate?
# regular income
# 494
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What did CDEL do with the coupon payments?
# defaulted
# 495
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the price of Tata Technologies Ltd.
# Rs 989.45
# 496
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the state advantage?
# the Vizhinjam container port and an already established ecosystem for EV charging
# question: What type of auto has Kerala Automobiles produced?
# electric
# 497
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: How many people will have visited Paris by Sunday night?
# 11.3 million
# 498
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the main problem with Cisco's mainstay business?
# supply-chain constraints
# 499
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What will happen to OPaL?
# change the status of OPaL into subsidiary of ONGC
# 500
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the decline in the June quarter?
# The net profit
# 501
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What factors did the firm blame for the weak performance in the June quarter?
# recent Lok Sabha elections, weather and slowdown
# 502
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is Prime Video hoping to do with its live sports?
# capture a greater share of the $28.75 billion in digital advertising revenue
# 503
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: Praveena Rai is a banker with over 25 years of experience.
# Praveena Rai is a banker with over 25 years of experience
# 504
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the company's net profit margin?
# 8.64 percent
# 505
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the question that generates the most questions?
# []
# 506
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the net profit of the quarter?
# Rs 2140.72 crore
# 507
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What kind of press conference did Mohanty give?
# post results
# 508
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the expected price of the deal?
# Rs 1,135/unit
# 509
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the sales volume growth for the June quarter?
# 14.3%
# 510
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the jump in net profit in the first quarter of FY25?
# Rs 174.2 crore
# 511
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the biggest increase in revenue from operations?
# Rs 1,278 crore
# 512
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What will the loan proceeds be used for?
# to finance the 300.3-MW wind energy project
# 513
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What did the people say Vedanta only mandated advisers for?
# the possible sale of the steel business
# question: What has Intel said it would prioritize?
# electronics and semiconductors
# 514
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the stock price of the state-run company?
# 6 percent
# 515
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What has caused Byju's boardroom exits?
# mismanagement
# 516
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the opportunity size big?
# the opportunity size is big
# 517
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What does the notice ask M&M about the GST liability?
# show-cause
# 518
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the reason for the recall?
# possible defect in steering gear box assembly
# 519
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the Q1 FY25 results?
# Net profit at Rs 265 crore
# question: What was the increase in operating EBITDA?
# jumped manyfold to Rs 284 crore
# 520
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the reason for the two-notch rating upgrade?
# the automaker’s revenue growth, improving profitability and debt reduction
# 521
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the net profit of tyre maker in Q1FY24?
# Rs 397 crore
# 522
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the reason for Ambani's decision?
# Covid-19 outbreak in India
# 523
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: How many artisans have been on Amazon?
# More than 2,500
# 524
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: How long will Setty be in office?
# three years
# 525
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What will Suzlon Group acquire in 18 months?
# 25 percent
# 526
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What has caused the Prime Minister of Pakistan to quit?
# job quota
# 527
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What kind of notices were sent?
# unpaid taxes on the import of services by Indian branches from their head offices
# 528
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the target turnover of the venture?
# Rs 8,000-8,500 crore
# question: When is the consumer electronics business expected to launch?
# July-September quarter
# 529
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What is the current state of the bank's wealth management unit?
# old
# 530
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: Has Microsoft had a good year?
# The company’s best-known business of selling personal computers has struggled
# 531
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What did India's second largest telecom operator say about its financials?
# robust balance sheet
# 532
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# Device set to use cuda:0
# question: What was the base deal size?
# Rs 5,861 crore

# %%
qa_pairs
# Out:
# [('question: How much money has KRAFTON invested in Indian startups?',
#   '$160 million'),
#  ("question: What was the BSA's relaunch in 2021?",
#   'BSA was relaunched in 2021'),
#  ('question: What is the name of the brand that is owned by Classic Legends?',
#   'Jawa and Yezdi motorcycle'),
#  ('question: What was the increase in the subscriber base in Q1FY24?',
#   '122.9 million'),
#  ('question: What is the growth of the construction chemicals and waterproofing segments?',
#   'strong'),
#  ('question: What is the future of stock returns?', 'once-reliable'),
#  ('question: What is the trend of Indian food delivery?',
#   'shifting away from rigid statistical norms, embracing diverse and fusion cuisines'),
#  ('question: What is the impact of the new offerings?',
#   'growing consumer appetite for variety'),
#  ('question: What kind of EVs will Gentari deploy for Amazon?', 'pact'),
#  ('question: What did the integrated producer say it was unable to comment on media speculation?',
#   'rumors'),
#  ('question: How much did the company raise in a round led by Force Ventures?',
#   'Rs 11 crore'),
#  ('question: What did the NCLT order do?',
#   'permitting the reclassification and transfer of funds from general reserves to retained earnings'),
#  ('question: How much debt did Hindustan Zinc have as of March 31, 2024?',
#   'Rs 8,722 crore'),
#  ("question: What was the SEBI's response to the Adani case?", 'This comment'),
#  ('question: What is the amount of funding the IIHL submitted to the Monitoring Committee?',
#   'Rs 7,300 crore'),
#  ('question: What was the deadline for the term sheet?', '4 p.m. on August 8'),
#  ("question: What did Hindenburg's report suggest about Adani's confidence in operating without",
#   "Adani's confidence in operating without serious regulatory intervention"),
#  ('question: What type of income can a REIT generate?', 'regular income'),
#  ('question: What did CDEL do with the coupon payments?', 'defaulted'),
#  ('question: What was the price of Tata Technologies Ltd.', 'Rs 989.45'),
#  ('question: What is the state advantage?',
#   'the Vizhinjam container port and an already established ecosystem for EV charging'),
#  ('question: What type of auto has Kerala Automobiles produced?', 'electric'),
#  ('question: How many people will have visited Paris by Sunday night?',
#   '11.3 million'),
#  ("question: What is the main problem with Cisco's mainstay business?",
#   'supply-chain constraints'),
#  ('question: What will happen to OPaL?',
#   'change the status of OPaL into subsidiary of ONGC'),
#  ('question: What was the decline in the June quarter?', 'The net profit'),
#  ('question: What factors did the firm blame for the weak performance in the June quarter?',
#   'recent Lok Sabha elections, weather and slowdown'),
#  ('question: What is Prime Video hoping to do with its live sports?',
#   'capture a greater share of the $28.75 billion in digital advertising revenue'),
#  ('question: Praveena Rai is a banker with over 25 years of experience.',
#   'Praveena Rai is a banker with over 25 years of experience'),
#  ("question: What was the company's net profit margin?", '8.64 percent'),
#  ('question: What is the question that generates the most questions?', '[]'),
#  ('question: What was the net profit of the quarter?', 'Rs 2140.72 crore'),
#  ('question: What kind of press conference did Mohanty give?', 'post results'),
#  ('question: What is the expected price of the deal?', 'Rs 1,135/unit'),
#  ('question: What was the sales volume growth for the June quarter?', '14.3%'),
#  ('question: What was the jump in net profit in the first quarter of FY25?',
#   'Rs 174.2 crore'),
#  ('question: What was the biggest increase in revenue from operations?',
#   'Rs 1,278 crore'),
#  ('question: What will the loan proceeds be used for?',
#   'to finance the 300.3-MW wind energy project'),
#  ('question: What did the people say Vedanta only mandated advisers for?',
#   'the possible sale of the steel business'),
#  ('question: What has Intel said it would prioritize?',
#   'electronics and semiconductors'),
#  ('question: What was the stock price of the state-run company?', '6 percent'),
#  ("question: What has caused Byju's boardroom exits?", 'mismanagement'),
#  ('question: What is the opportunity size big?',
#   'the opportunity size is big'),
#  ('question: What does the notice ask M&M about the GST liability?',
#   'show-cause'),
#  ('question: What is the reason for the recall?',
#   'possible defect in steering gear box assembly'),
#  ('question: What was the Q1 FY25 results?', 'Net profit at Rs 265 crore'),
#  ('question: What was the increase in operating EBITDA?',
#   'jumped manyfold to Rs 284 crore'),
#  ('question: What is the reason for the two-notch rating upgrade?',
#   'the automaker’s revenue growth, improving profitability and debt reduction'),
#  ('question: What was the net profit of tyre maker in Q1FY24?',
#   'Rs 397 crore'),
#  ("question: What was the reason for Ambani's decision?",
#   'Covid-19 outbreak in India'),
#  ('question: How many artisans have been on Amazon?', 'More than 2,500'),
#  ('question: How long will Setty be in office?', 'three years'),
#  ('question: What will Suzlon Group acquire in 18 months?', '25 percent'),
#  ('question: What has caused the Prime Minister of Pakistan to quit?',
#   'job quota'),
#  ('question: What kind of notices were sent?',
#   'unpaid taxes on the import of services by Indian branches from their head offices'),
#  ('question: What is the target turnover of the venture?',
#   'Rs 8,000-8,500 crore'),
#  ('question: When is the consumer electronics business expected to launch?',
#   'July-September quarter'),
#  ("question: What is the current state of the bank's wealth management unit?",
#   'old'),
#  ('question: Has Microsoft had a good year?',
#   'The company’s best-known business of selling personal computers has struggled'),
#  ("question: What did India's second largest telecom operator say about its financials?",
#   'robust balance sheet'),
#  ('question: What was the base deal size?', 'Rs 5,861 crore')]

# %%
qa_df = pd.DataFrame(qa_pairs, columns=["Ques", "Ans"])
qa_df["Ques"] = qa_df["Ques"].str.replace("question: ", "", regex=False)
qa_df
# Out:
#                                                   Ques  \
# 0         What did Purple Fabric share with investors?
# 1         What was the effect of the shot on patients?
# 2    What has the industry sought to clear the back...
# 3    What is the expected outcome of the sale of th...
# 4        What has Tata Steel said is 'extremely high'?
# ..                                                 ...
# 274  What is the government's response to Rajaa's c...
# 275  What did the FTC say Amazon was using an algor...
# 276  What has Amazon said in court papers about its...
# 277       Where can you buy Augustinus Bader products?
# 278  What is the main reason for the shut down of t...
#
#                                                    Ans
# 0                                       a presentation
# 1             lose an average of 20.4% of their weight
# 2    transmission charges waiver and penalty for no...
# 3                                          $30 billion
# 4                the penalty imposed on its Dutch unit
# ..                                                 ...
# 274             they should return to work immediately
# 275                                         Amazon.com
# 276               it stopped using the program in 2019
# 277                                             online
# 278                       Automating 'low-value' tasks
#
# [279 rows x 2 columns]

# %%
qa_df1 = pd.DataFrame(qa_pairs, columns=["Ques", "Ans"])
qa_df1["Ques"] = qa_df1["Ques"].str.replace("question: ", "", regex=False)
qa_df1
# Out:
#                                                   Ques  \
# 0    What two copper mines will Hindalco Industries...
# 1       How many stock options were granted to Zomato?
# 2    What has MTNL caused banks to take action agai...
# 3         What is the final approval for registration?
# 4    What was the growth in domestic jewellery oper...
# ..                                                 ...
# 288  What other Indian companies own or have a stak...
# 289                                   Who won the bid?
# 290                  What did Subramanian Swamy claim?
# 291  What did the Quest Smart Alpha Sector Rotation...
# 292  What is the advice given to passengers on the ...
#
#                                                    Ans
# 0              Hindustan Copper Ltd's two copper mines
# 1                                         330.17 crore
# 2                                  non-payment of dues
# 3    fulfillment by the Company and BlackRock of th...
# 4                                       25 percent YoY
# ..                                                 ...
# 288                          Tatas, Reliance, Mahindra
# 289                                      The POWERGRID
# 290  Axis Bank made undue profits from share transa...
# 291                                       Rs 500 crore
# 292     connect with the SpiceJet helpdesk/call centre
#
# [293 rows x 2 columns]

# %%
qa_df2 = pd.DataFrame(qa_pairs, columns=["Ques", "Ans"])
qa_df2["Ques"] = qa_df2["Ques"].str.replace("question: ", "", regex=False)
qa_df2
# Out:
#                                                  Ques  \
# 0   How much money has KRAFTON invested in Indian ...
# 1                What was the BSA's relaunch in 2021?
# 2   What is the name of the brand that is owned by...
# 3   What was the increase in the subscriber base i...
# 4   What is the growth of the construction chemica...
# ..                                                ...
# 56  When is the consumer electronics business expe...
# 57  What is the current state of the bank's wealth...
# 58                     Has Microsoft had a good year?
# 59  What did India's second largest telecom operat...
# 60                       What was the base deal size?
#
#                                                   Ans
# 0                                        $160 million
# 1                          BSA was relaunched in 2021
# 2                           Jawa and Yezdi motorcycle
# 3                                       122.9 million
# 4                                              strong
# ..                                                ...
# 56                             July-September quarter
# 57                                                old
# 58  The company’s best-known business of selling p...
# 59                               robust balance sheet
# 60                                     Rs 5,861 crore
#
# [61 rows x 2 columns]

# %%
qa_df_merged = pd.concat([qa_df, qa_df1])
qa_df_merged = pd.concat([qa_df_merged, qa_df2])
qa_df_merged.drop_duplicates()
qa_df_merged
# Out:
#                                                  Ques  \
# 0        What did Purple Fabric share with investors?
# 1        What was the effect of the shot on patients?
# 2   What has the industry sought to clear the back...
# 3   What is the expected outcome of the sale of th...
# 4       What has Tata Steel said is 'extremely high'?
# ..                                                ...
# 56  When is the consumer electronics business expe...
# 57  What is the current state of the bank's wealth...
# 58                     Has Microsoft had a good year?
# 59  What did India's second largest telecom operat...
# 60                       What was the base deal size?
#
#                                                   Ans
# 0                                      a presentation
# 1            lose an average of 20.4% of their weight
# 2   transmission charges waiver and penalty for no...
# 3                                         $30 billion
# 4               the penalty imposed on its Dutch unit
# ..                                                ...
# 56                             July-September quarter
# 57                                                old
# 58  The company’s best-known business of selling p...
# 59                               robust balance sheet
# 60                                     Rs 5,861 crore
#
# [632 rows x 2 columns]

# %%
qa_df_merged.to_csv('/mnt/c/Users/ankku/Downloads/moneycontrol_companies_qa.csv', index = False)
